# %% [markdown]
# # ===============================
# #� Project 3: Exploratory Data Analysis (EDA)
# # Dataset: House Prices - Advanced Regression Techniques (Kaggle)
# # ===============================# =

# %% [markdown]
# 1. Project Objective
#
# The objective of this project is to perform a comprehensive Exploratory Data Analysis (EDA) on the House Prices dataset.
# We aim to:
#
# Understand the structure of the dataset.
#
# Discover hidden patterns and relationships.
#
# Identify anomalies and outliers.
#
# Generate meaningful insights about the housing market.

# %%
#  Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# 🎨 Plot Settings
sns.set_style("whitegrid") 
sns.set_palette("Set2")     
pd.set_option("display.float_format", lambda x: "%.2f" % x)  # Format

# %% [raw]
# # ===============================
# # 1. Data Loading & Inspection
# # ===============================

# %%
df = pd.read_csv("C:/Users/tusha/Downloads/train.csv")

print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (1460, 81)

# %%
display(df.head(20))
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL        65.00     8450   Pave   NaN      Reg
# 1    2          20       RL        80.00     9600   Pave   NaN      Reg
# 2    3          60       RL        68.00    11250   Pave   NaN      IR1
# 3    4          70       RL        60.00     9550   Pave   NaN      IR1
# 4    5          60       RL        84.00    14260   Pave   NaN      IR1
# 5    6          50       RL        85.00    14115   Pave   NaN      IR1
# 6    7          20       RL        75.00    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM        51.00     6120   Pave   NaN      Reg
# 9   10         190       RL        50.00     7420   Pave   NaN      Reg
# 10  11          20       RL        70.00    11200   Pave   NaN      Reg
# 11  12          60       RL        85.00    11924   Pave   NaN      IR1
# ...

# %%
display(df.tail( 30))
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1430  1431          60       RL        60.00    21930   Pave   NaN      IR3
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1432  1433          30       RL        60.00    10800   Pave  Grvl      Reg
# 1433  1434          60       RL        93.00    10261   Pave   NaN      IR1
# 1434  1435          20       RL        80.00    17400   Pave   NaN      Reg
# 1435  1436          20       RL        80.00     8400   Pave   NaN      Reg
# 1436  1437          20       RL        60.00     9000   Pave   NaN      Reg
# 1437  1438          20       RL        96.00    12444   Pave   NaN      Reg
# 1438  1439          20       RM        90.00     7407   Pave   NaN      Reg
# 1439  1440          60       RL        80.00    11584   Pave   NaN      Reg
# 1440  1441          70       RL        79.00    11526   Pave   NaN      IR1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe().T
# Out:
#                 count      mean      std      min       25%       50%  \
# Id            1460.00    730.50   421.61     1.00    365.75    730.50
# MSSubClass    1460.00     56.90    42.30    20.00     20.00     50.00
# LotFrontage   1201.00     70.05    24.28    21.00     59.00     69.00
# LotArea       1460.00  10516.83  9981.26  1300.00   7553.50   9478.50
# OverallQual   1460.00      6.10     1.38     1.00      5.00      6.00
# OverallCond   1460.00      5.58     1.11     1.00      5.00      5.00
# YearBuilt     1460.00   1971.27    30.20  1872.00   1954.00   1973.00
# YearRemodAdd  1460.00   1984.87    20.65  1950.00   1967.00   1994.00
# MasVnrArea    1452.00    103.69   181.07     0.00      0.00      0.00
# BsmtFinSF1    1460.00    443.64   456.10     0.00      0.00    383.50
# BsmtFinSF2    1460.00     46.55   161.32     0.00      0.00      0.00
# BsmtUnfSF     1460.00    567.24   441.87     0.00    223.00    477.50
# ...

# %%
# ===============================
# 2. Missing Values Analysis
# ===============================
missing_percent = (df.isnull().sum()/len(df))*100
missing_data = pd.DataFrame({"MissingCount": df.isnull().sum(),
                             "MissingPercent": missing_percent})
missing_data = missing_data[missing_data["MissingCount"] > 0].sort_values("MissingPercent", ascending=False)
display(missing_data.head(20))
# Out:
#               MissingCount  MissingPercent
# PoolQC                1453           99.52
# MiscFeature           1406           96.30
# Alley                 1369           93.77
# Fence                 1179           80.75
# MasVnrType             872           59.73
# FireplaceQu            690           47.26
# LotFrontage            259           17.74
# GarageType              81            5.55
# GarageYrBlt             81            5.55
# GarageFinish            81            5.55
# GarageQual              81            5.55
# GarageCond              81            5.55
# BsmtFinType2            38            2.60
# BsmtExposure            38            2.60
# BsmtFinType1            37            2.53
# BsmtCond                37            2.53
# BsmtQual                37            2.53
# MasVnrArea               8            0.55
# Electrical               1            0.07

# %%
plt.figure(figsize=(10,6))
missing_data["MissingPercent"].plot(kind="bar")
plt.title("Top Missing Features (%)")
plt.ylabel("Percent Missing")
plt.show()

# %%
# ===============================
# 3. Duplicate Check
# ===============================
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# ===============================
# 4. Outlier Detection
# ===============================
plt.figure(figsize=(8,5))
sns.boxplot(x=df["SalePrice"])
plt.title("Boxplot of SalePrice")
plt.show()


outliers = df[(df['GrLivArea'] > 4000) & (df['SalePrice'] < 300000)]
print("Potential Outliers (GrLivArea vs SalePrice):")
display(outliers[["Id","GrLivArea","SalePrice","Neighborhood"]])
# Out:
# Potential Outliers (GrLivArea vs SalePrice):
#         Id  GrLivArea  SalePrice Neighborhood
# 523    524       4676     184750      Edwards
# 1298  1299       5642     160000      Edwards

# %%
# ===============================
# 5. Univariate Analysis
# ===============================
# Numerical variables
num_vars = df.select_dtypes(include=[np.number]).columns
summary = pd.DataFrame({
    "Mean": df[num_vars].mean(),
    "Median": df[num_vars].median(),
    "TrimmedMean": df[num_vars].apply(lambda x: stats.trim_mean(x, 0.1)),
    "Variance": df[num_vars].var(),
    "StdDev": df[num_vars].std(),
    "Range": df[num_vars].max() - df[num_vars].min()
})
display(summary.head())
# Out:
#                 Mean  Median  TrimmedMean    Variance  StdDev     Range
# Id            730.50  730.50       730.50   177755.00  421.61   1459.00
# MSSubClass     56.90   50.00        49.15     1789.34   42.30    170.00
# LotFrontage    70.05   69.00          NaN      589.75   24.28    292.00
# LotArea     10516.83 9478.50      9563.28 99625649.65 9981.26 213945.00
# OverallQual     6.10    6.00         6.08        1.91    1.38      9.00

# %%
# Distribution of SalePrice
plt.figure(figsize=(10,6))
sns.histplot(df["SalePrice"], kde=True)
plt.title("Distribution of SalePrice")
plt.show()

# %%
# Log transformation
plt.figure(figsize=(10,6))
sns.histplot(np.log1p(df["SalePrice"]), kde=True)
plt.title("Log-Transformed SalePrice")
plt.show()

# %%
# Categorical variables
cat_vars = df.select_dtypes(include=["object"]).columns
for col in cat_vars[:3]:  # show first 3 as example
    print(f"\n{col} value counts:")
    print(df[col].value_counts().head())
    print("Mode:", df[col].mode()[0])

    plt.figure(figsize=(8,4))
    sns.countplot(y=col, data=df, order=df[col].value_counts().index)
    plt.title(f"{col} Frequency")
    plt.show()
# Out:
# MSZoning value counts:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# Mode: RL
# Street value counts:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
# Mode: Pave
# Alley value counts:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64
# Mode: Grvl

# %%
# ===============================
# 6. Bivariate Analysis
# ===============================
# Scatter: GrLivArea vs SalePrice
plt.figure(figsize=(8,5))
sns.scatterplot(x="GrLivArea", y="SalePrice", data=df, alpha=0.6)
plt.title("GrLivArea vs SalePrice")
plt.show()

# %%
# Correlation Matrix
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Top correlations with SalePrice
top_corr = corr["SalePrice"].abs().sort_values(ascending=False).head(15)
plt.figure(figsize=(8,6))
sns.barplot(x=top_corr.values, y=top_corr.index)
plt.title("Top 15 Correlations with SalePrice")
plt.show()

# %%
# Boxplot: Neighborhood vs SalePrice
plt.figure(figsize=(14,6))
neigh_order = df.groupby("Neighborhood")["SalePrice"].median().sort_values().index
sns.boxplot(x="Neighborhood", y="SalePrice", data=df, order=neigh_order)
plt.xticks(rotation=90)
plt.title("SalePrice by Neighborhood")
plt.show()

# %%
# ===============================
# 7. Dataset-Specific EDA
# ===============================

# Year Built vs SalePrice (Median)
# Year Built vs SalePrice (Median)
plt.figure(figsize=(12,6))
sns.lineplot(x="YearBuilt", y="SalePrice", data=df, estimator=np.median, errorbar=None)
plt.title("Median SalePrice by Year Built")
plt.xlabel("Year Built")
plt.ylabel("SalePrice")
plt.tight_layout()
plt.show()

# %%
# OverallQual vs SalePrice
plt.figure(figsize=(10,6))
sns.boxplot(x="OverallQual", y="SalePrice", data=df)
plt.title("SalePrice by Overall Quality")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="GarageCars", y="SalePrice", data=df)
plt.title("SalePrice by Garage Capacity")
plt.show()

# %%
# Basement area
plt.figure(figsize=(8,5))
sns.scatterplot(x="TotalBsmtSF", y="SalePrice", data=df)
plt.title("Total Basement Area vs SalePrice")
plt.show()

# %%
# Living area vs Basement
plt.figure(figsize=(8,5))
sns.scatterplot(x="GrLivArea", y="TotalBsmtSF", data=df, alpha=0.6)
plt.title("GrLivArea vs TotalBsmtSF")
plt.show()

# %%
# Neighborhood premium vs low-price
neighborhood_prices = df.groupby("Neighborhood")["SalePrice"].median().sort_values(ascending=False)
print(" Premium Neighborhoods:\n", neighborhood_prices.head(5))
print("\n Lower-Price Neighborhoods:\n", neighborhood_prices.tail(5))
# Out:
#  Premium Neighborhoods:
#  Neighborhood
# NridgHt   315000.00
# NoRidge   301500.00
# StoneBr   278000.00
# Timber    228475.00
# Somerst   225500.00
# Name: SalePrice, dtype: float64
#
#  Lower-Price Neighborhoods:
#  Neighborhood
# Edwards   121750.00
# OldTown   119000.00
# BrDale    106000.00
# IDOTRR    103000.00
# MeadowV    88000.00
# Name: SalePrice, dtype: float64

# %%
# Select numeric features and compute correlations
num_df = df.select_dtypes(include=[np.number])
corr_all = num_df.corr()['SalePrice'].drop('SalePrice').sort_values(ascending=False)

# Top k correlated features
top_k = 12
top_corr = corr_all.head(top_k)
display(top_corr.to_frame('corr_with_SalePrice'))

# 📊 Barplot of top correlations
plt.figure(figsize=(8,5))
sns.barplot(x=top_corr.values, y=top_corr.index, hue=top_corr.index, palette='coolwarm', legend=False)
plt.title('Top correlations with SalePrice')
plt.xlabel('Pearson correlation')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# 🔥 Focused heatmap for top features + SalePrice
sel_feats = ['SalePrice'] + top_corr.index.tolist()
plt.figure(figsize=(8,6))
sns.heatmap(num_df[sel_feats].corr(), annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Heatmap: SalePrice and top-correlated features')
plt.tight_layout()
plt.show()
# Out:
#               corr_with_SalePrice
# OverallQual                  0.79
# GrLivArea                    0.71
# GarageCars                   0.64
# GarageArea                   0.62
# TotalBsmtSF                  0.61
# 1stFlrSF                     0.61
# FullBath                     0.56
# TotRmsAbvGrd                 0.53
# YearBuilt                    0.52
# YearRemodAdd                 0.51
# GarageYrBlt                  0.49
# MasVnrArea                   0.48

# %%
# SaleCondition
plt.figure(figsize=(10,5))
sns.boxplot(x="SaleCondition", y="SalePrice", data=df)
plt.title("SalePrice by Sale Condition")
plt.show()

# %%
# Basement & Garage Features Correlation
features = ["TotalBsmtSF","GarageArea","GarageCars","1stFlrSF","GrLivArea","SalePrice"]
plt.figure(figsize=(8,6))
sns.heatmap(df[features].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Basement/Garage Features Correlation")
plt.show()

# %%
# Extreme price outliers
outliers_ext = df[(df['SalePrice'] > 700000) | (df['SalePrice'] < 50000)]
print("Extreme Price Outliers:")
display(outliers_ext[["Id","SalePrice","GrLivArea","Neighborhood","OverallQual"]])
# Out:
# Extreme Price Outliers:
#         Id  SalePrice  GrLivArea Neighborhood  OverallQual
# 30      31      40000       1317       IDOTRR            4
# 495    496      34900        720       IDOTRR            4
# 533    534      39300        334      BrkSide            1
# 691    692     755000       4316      NoRidge           10
# 916    917      35311        480       IDOTRR            2
# 968    969      37900        968      OldTown            3
# 1182  1183     745000       4476      NoRidge           10

# %%
# ===============================
# 8. Final Insights (Markdown)
# ===============================

"""
# 🔑 Final Dataset-Specific Insights

1. **Quality is King:** `OverallQual` is the strongest driver of SalePrice — higher quality nearly linearly increases price.  
2. **Bigger = Pricier:** Living area (`GrLivArea`) and basement size (`TotalBsmtSF`) strongly predict SalePrice. Outliers exist with very large houses selling cheap.  
3. **Neighborhood Matters:** *StoneBr, NridgHt, NoRidge* are premium neighborhoods, while *IDOTRR, BrDale, MeadowV* are much cheaper.  
4. **Garage & Modern Features:** Larger garages and newer builds fetch higher prices. Houses with no garage are consistently cheaper.  
5. **Sale Conditions Influence:** Normal sales are priced higher; abnormal/family sales are discounted.  
6. **Data Quality:** Features like `PoolQC`, `Fence`, and `Alley` represent missing = "None", while `LotFrontage` requires median imputation by neighborhood.  

👉 These findings show both **statistical patterns** and **real estate economics** hidden in the dataset.
"""
# Out:
# '\n# 🔑 Final Dataset-Specific Insights\n\n1. **Quality is King:** `OverallQual` is the strongest driver of SalePrice — higher quality nearly linearly increases price.  \n2. **Bigger = Pricier:** Living area (`GrLivArea`) and basement size (`TotalBsmtSF`) strongly predict SalePrice. Outliers exist with very large houses selling cheap.  \n3. **Neighborhood Matters:** *StoneBr, NridgHt, NoRidge* are premium neighborhoods, while *IDOTRR, BrDale, MeadowV* are much cheaper.  \n4. **Garage & Modern Features:** Larger garages and newer builds fetch higher prices. Houses with no garage are consistently cheaper.  \n5. **Sale Conditions Influence:** Normal sales are priced higher; abnormal/family sales are discounted.  \n6. **Data Quality:** Features like `PoolQC`, `Fence`, and `Alley` represent missing = "None", while `LotFrontage` requires median imputation by neighborhood.  \n\n👉 These findings show both **statistical patterns** and **real estate economics** hidden in the dataset.\n'
